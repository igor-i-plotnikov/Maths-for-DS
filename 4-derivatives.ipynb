# %% [markdown]
# # Домашнее задание "Математический анализ. Производная".

# %% [markdown]
# ### Уровень 0:

# %% [markdown]
# Посчитайте значение первой и второй производной функции:
#
# $f(x) = x^5 + 4sin(2x) + cos(3x+3)$
#
# В точке x = 1.

# %%
from sympy.abc import x, y
from sympy import sin, cos, symbols, diff

# %%
f = x**5 + 4*sin(2*x) * cos(3*x + 3)
diff(f, x)
# Out:
# 5*x**4 - 12*sin(2*x)*sin(3*x + 3) + 8*cos(2*x)*cos(3*x + 3)

# %%
diff(f, x, 2)
# Out:
# 4*(5*x**3 - 13*sin(2*x)*cos(3*(x + 1)) - 12*sin(3*(x + 1))*cos(2*x))

# %% [markdown]
# ### Уровень 1:

# %% [markdown]
# Постройте график первой и второй производной функции:
#
# $f(x) = sin^5(2x+1)$
#
# На отрезке [-5; 5].

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.misc import derivative

# %%
def f(x):
    return sin(2*x + 1)**5

# %%
def der1(x):
    return derivative(f, x)

# %%
def der2(x):
    return derivative(f, x, 2)

# %%
xs = np.linspace(-6, 6)

# %%
plt.plot(xs, [f(x) for x in xs], color='green', label='Function')
plt.plot(xs, [der1(x) for x in xs], color='blue', label='Derivative1')
plt.plot(xs, [der2(x) for x in xs], color='purple', label='Derivative2')
